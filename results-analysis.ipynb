# %%
# %pip install pandas
# %pip install numpy
# %pip install spacy
# %pip install -U scikit-learn
# %pip install seaborn
# %pip install transformers
# %pip install fasttext
# %pip install lazypredict
# %pip install gensim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
def get_avg_folds(df, models):
    result = pd.DataFrame(columns=["Model","Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"], index=np.arange(len(models)))

    for i, model in enumerate(models):
        model_folds = df.loc[df['Model'] == model]
        result.loc[i]["Model"] = model
        result.loc[i]["Accuracy"] = round(np.mean(model_folds['Accuracy'].to_list()), 3)
        result.loc[i]["Balanced Accuracy"] = round(np.mean(model_folds['Balanced Accuracy'].to_list()), 3)
        result.loc[i]["Precision-Macro"] = round(np.mean(model_folds['Precision-Macro'].to_list()), 3)
        result.loc[i]["Precision-Weighted"] = round(np.mean(model_folds['Precision-Weighted'].to_list()), 3)
        result.loc[i]["Recall-Macro"] = round(np.mean(model_folds['Recall-Macro'].to_list()), 3)
        result.loc[i]["Recall-Weighted"] = round(np.mean(model_folds['Recall-Weighted'].to_list()), 3)
        result.loc[i]["F1-Score-Macro"] = round(np.mean(model_folds['F1-Score-Macro'].to_list()), 3)
        result.loc[i]["F1-Score-Weighted"] = round(np.mean(model_folds['F1-Score-Weighted'].to_list()), 3)

    return result

# %% [markdown]
# ## FASTTEXT

# %%
df = pd.read_excel("results/10-Fold-fasttext-davidson.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy
# 0       1      AdaBoostClassifier     0.644              0.362  \
# 1       1       BaggingClassifier     0.994              0.911
# 2       1             BernoulliNB     0.869              0.781
# 3       1  CalibratedClassifierCV     0.988              0.851
# 4       1  DecisionTreeClassifier     0.989              0.910
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.947              0.593
# 246    10       RidgeClassifierCV     0.947              0.593
# 247    10           SGDClassifier     0.973              0.694
# 248    10                     SVC     0.975              0.804
# 249    10          LGBMClassifier     0.310              0.180
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted
# 0              0.262               0.435         0.362            0.644  \
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro
# 0              AdaBoostClassifier    0.631             0.372           0.287  \
# 1               BaggingClassifier    0.995              0.93           0.945
# 2                     BernoulliNB    0.858             0.723           0.682
# 3          CalibratedClassifierCV     0.99             0.867           0.912
# 4          DecisionTreeClassifier    0.992             0.931           0.938
# 5                 DummyClassifier    0.414             0.127           0.052
# 6             ExtraTreeClassifier    0.921             0.715           0.711
# 7            ExtraTreesClassifier    0.985              0.81           0.876
# 8                      GaussianNB    0.923             0.897           0.717
# 9            KNeighborsClassifier    0.861             0.588           0.733
# 10               LabelPropagation    0.266             0.161           0.622
# ...

# %%
result.to_excel("results/avg-10-Fold-fasttext-davidson.xlsx")

# %% [markdown]
# ## GLOVE

# %%
df = pd.read_excel("results/10-Fold-glove-davidson.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy
# 0       1      AdaBoostClassifier     0.644              0.360  \
# 1       1       BaggingClassifier     0.994              0.913
# 2       1             BernoulliNB     0.768              0.663
# 3       1  CalibratedClassifierCV     0.987              0.891
# 4       1  DecisionTreeClassifier     0.990              0.932
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.945              0.592
# 246    10       RidgeClassifierCV     0.945              0.592
# 247    10           SGDClassifier     0.974              0.699
# 248    10                     SVC     0.974              0.791
# 249    10          LGBMClassifier     0.529              0.205
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted
# 0              0.280               0.448         0.360            0.644  \
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro
# 0              AdaBoostClassifier     0.64             0.408           0.344  \
# 1               BaggingClassifier    0.995             0.929           0.962
# 2                     BernoulliNB    0.765             0.658           0.511
# 3          CalibratedClassifierCV     0.99             0.863           0.904
# 4          DecisionTreeClassifier    0.992             0.915           0.904
# 5                 DummyClassifier    0.414             0.127           0.052
# 6             ExtraTreeClassifier    0.921             0.723           0.725
# 7            ExtraTreesClassifier    0.982             0.796           0.888
# 8                      GaussianNB     0.92             0.897           0.706
# 9            KNeighborsClassifier    0.852             0.571           0.708
# 10               LabelPropagation    0.364             0.228           0.662
# ...

# %%
result.to_excel("results/avg-10-Fold-glove-davidson.xlsx")

# %% [markdown]
# ## BERT

# %%
df = pd.read_excel("results/10-Fold-BERT-davidson.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy
# 0       1      AdaBoostClassifier     0.642              0.357  \
# 1       1       BaggingClassifier     0.996              0.942
# 2       1             BernoulliNB     0.827              0.656
# 3       1  CalibratedClassifierCV     0.989              0.932
# 4       1  DecisionTreeClassifier     0.993              0.895
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.948              0.595
# 246    10       RidgeClassifierCV     0.948              0.595
# 247    10           SGDClassifier     0.979              0.711
# 248    10                     SVC     0.981              0.797
# 249    10          LGBMClassifier     0.994              0.956
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted
# 0              0.262               0.434         0.357            0.642  \
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro
# 0              AdaBoostClassifier    0.613             0.411           0.343  \
# 1               BaggingClassifier    0.996             0.943           0.979
# 2                     BernoulliNB    0.825             0.656           0.655
# 3          CalibratedClassifierCV    0.991             0.852           0.903
# 4          DecisionTreeClassifier    0.994             0.942           0.946
# 5                 DummyClassifier    0.414             0.127           0.052
# 6             ExtraTreeClassifier    0.904             0.731           0.729
# 7            ExtraTreesClassifier    0.989             0.824            0.89
# 8                      GaussianNB    0.307             0.407           0.459
# 9            KNeighborsClassifier    0.912             0.661           0.773
# 10               LabelPropagation     0.87             0.667           0.762
# ...

# %%
result.to_excel("results/avg-10-Fold-BERT-davidson.xlsx")

# %% [markdown]
# ## TFIDF

# %%
df = pd.read_excel("results/10-Fold-tfdif-davidson.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy
# 0       1      AdaBoostClassifier     0.628              0.262  \
# 1       1       BaggingClassifier     0.995              0.940
# 2       1             BernoulliNB     0.883              0.753
# 3       1  CalibratedClassifierCV     0.990              0.910
# 4       1  DecisionTreeClassifier     0.993              0.927
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.946              0.594
# 246    10       RidgeClassifierCV     0.946              0.594
# 247    10           SGDClassifier     0.976              0.699
# 248    10                     SVC     0.973              0.738
# 249    10          LGBMClassifier     0.422              0.126
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted
# 0              0.373               0.546         0.262            0.628  \
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro
# 0              AdaBoostClassifier    0.633             0.346           0.352  \
# 1               BaggingClassifier    0.996              0.95           0.979
# 2                     BernoulliNB    0.883             0.774           0.755
# 3          CalibratedClassifierCV     0.99             0.876           0.922
# 4          DecisionTreeClassifier    0.995             0.945           0.949
# 5                 DummyClassifier    0.414             0.127           0.052
# 6             ExtraTreeClassifier    0.968             0.851           0.837
# 7            ExtraTreesClassifier    0.994             0.928           0.974
# 8                      GaussianNB    0.246             0.303           0.489
# 9            KNeighborsClassifier    0.802             0.484           0.628
# 10               LabelPropagation    0.737             0.487           0.673
# ...

# %%
result.to_excel("results/avg-10-Fold-tfdif-davidson.xlsx")

# %% [markdown]
# ## WORD2VEC

# %%
df = pd.read_excel("results/10-Fold-word2vec-davidson.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy
# 0       1      AdaBoostClassifier     0.644              0.360  \
# 1       1       BaggingClassifier     0.993              0.914
# 2       1             BernoulliNB     0.800              0.665
# 3       1  CalibratedClassifierCV     0.986              0.880
# 4       1  DecisionTreeClassifier     0.988              0.867
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.946              0.596
# 246    10       RidgeClassifierCV     0.946              0.596
# 247    10           SGDClassifier     0.975              0.707
# 248    10                     SVC     0.973              0.800
# 249    10          LGBMClassifier     0.475              0.217
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted
# 0              0.261               0.434         0.360            0.644  \
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro
# 0              AdaBoostClassifier    0.636             0.395           0.308  \
# 1               BaggingClassifier    0.995             0.929           0.948
# 2                     BernoulliNB    0.802             0.699           0.557
# 3          CalibratedClassifierCV     0.99             0.878           0.905
# 4          DecisionTreeClassifier    0.992             0.889           0.912
# 5                 DummyClassifier    0.414             0.127           0.052
# 6             ExtraTreeClassifier    0.911               0.7           0.703
# 7            ExtraTreesClassifier    0.984             0.801           0.888
# 8                      GaussianNB    0.919             0.897           0.704
# 9            KNeighborsClassifier    0.854             0.565           0.695
# 10               LabelPropagation    0.367             0.227           0.649
# ...

# %%
result.to_excel("results/avg-10-Fold-word2vec-davidson.xlsx")

# %% [markdown]
# ## ANALYSIS

# %%
fasttext = pd.read_excel("results/avg-10-Fold-fasttext-davidson.xlsx")
del fasttext['Unnamed: 0']
fasttext = fasttext.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
fasttext
# Out:
#                             Model  Accuracy  Balanced Accuracy
# 1               BaggingClassifier     0.995              0.930  \
# 13                      LinearSVC     0.993              0.913
# 14             LogisticRegression     0.993              0.894
# 4          DecisionTreeClassifier     0.992              0.931
# 3          CalibratedClassifierCV     0.990              0.867
# 7            ExtraTreesClassifier     0.985              0.810
# 17                     Perceptron     0.983              0.834
# 16    PassiveAggressiveClassifier     0.983              0.781
# 19         RandomForestClassifier     0.983              0.774
# 12     LinearDiscriminantAnalysis     0.980              0.981
# 23                            SVC     0.978              0.800
# 22                  SGDClassifier     0.976              0.712
# 20                RidgeClassifier     0.948              0.603
# 21              RidgeClassifierCV     0.948              0.603
# ...

# %%
glove = pd.read_excel("results/avg-10-Fold-glove-davidson.xlsx")
del glove['Unnamed: 0']
glove = glove.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
glove
# Out:
#                             Model  Accuracy  Balanced Accuracy
# 1               BaggingClassifier     0.995              0.929  \
# 13                      LinearSVC     0.993              0.894
# 14             LogisticRegression     0.993              0.871
# 4          DecisionTreeClassifier     0.992              0.915
# 3          CalibratedClassifierCV     0.990              0.863
# 17                     Perceptron     0.982              0.807
# 7            ExtraTreesClassifier     0.982              0.796
# 16    PassiveAggressiveClassifier     0.981              0.786
# 12     LinearDiscriminantAnalysis     0.980              0.981
# 19         RandomForestClassifier     0.978              0.723
# 23                            SVC     0.977              0.788
# 22                  SGDClassifier     0.976              0.714
# 20                RidgeClassifier     0.946              0.602
# 21              RidgeClassifierCV     0.946              0.602
# ...

# %%
bert = pd.read_excel("results/avg-10-Fold-BERT-davidson.xlsx")
del bert['Unnamed: 0']
bert = bert.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
bert
# Out:
#                             Model  Accuracy  Balanced Accuracy
# 1               BaggingClassifier     0.996              0.943  \
# 14             LogisticRegression     0.996              0.938
# 13                      LinearSVC     0.994              0.955
# 4          DecisionTreeClassifier     0.994              0.942
# 3          CalibratedClassifierCV     0.991              0.852
# 7            ExtraTreesClassifier     0.989              0.824
# 19         RandomForestClassifier     0.987              0.811
# 12     LinearDiscriminantAnalysis     0.986              0.985
# 17                     Perceptron     0.985              0.882
# 16    PassiveAggressiveClassifier     0.982              0.813
# 22                  SGDClassifier     0.981              0.746
# 23                            SVC     0.978              0.828
# 21              RidgeClassifierCV     0.949              0.604
# 20                RidgeClassifier     0.949              0.604
# ...

# %%
tfdif = pd.read_excel("results/avg-10-Fold-tfdif-davidson.xlsx")
del tfdif['Unnamed: 0']
tfdif = tfdif.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
tfdif
# Out:
#                             Model  Accuracy  Balanced Accuracy
# 1               BaggingClassifier     0.996              0.950  \
# 4          DecisionTreeClassifier     0.995              0.945
# 7            ExtraTreesClassifier     0.994              0.928
# 19         RandomForestClassifier     0.994              0.906
# 13                      LinearSVC     0.992              0.915
# 14             LogisticRegression     0.992              0.888
# 3          CalibratedClassifierCV     0.990              0.876
# 12     LinearDiscriminantAnalysis     0.982              0.981
# 17                     Perceptron     0.982              0.855
# 16    PassiveAggressiveClassifier     0.982              0.812
# 22                  SGDClassifier     0.977              0.715
# 23                            SVC     0.973              0.742
# 6             ExtraTreeClassifier     0.968              0.851
# 20                RidgeClassifier     0.949              0.604
# ...

# %%
w2c = pd.read_excel("results/avg-10-Fold-word2vec-davidson.xlsx")
del w2c['Unnamed: 0']
w2c = w2c.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
w2c
# Out:
#                             Model  Accuracy  Balanced Accuracy
# 1               BaggingClassifier     0.995              0.929  \
# 13                      LinearSVC     0.993              0.907
# 14             LogisticRegression     0.993              0.894
# 4          DecisionTreeClassifier     0.992              0.889
# 3          CalibratedClassifierCV     0.990              0.878
# 7            ExtraTreesClassifier     0.984              0.801
# 16    PassiveAggressiveClassifier     0.983              0.791
# 17                     Perceptron     0.982              0.863
# 12     LinearDiscriminantAnalysis     0.980              0.981
# 19         RandomForestClassifier     0.977              0.721
# 23                            SVC     0.976              0.804
# 22                  SGDClassifier     0.976              0.717
# 20                RidgeClassifier     0.946              0.603
# 21              RidgeClassifierCV     0.946              0.603
# ...

# %% [markdown]
# # MFRC DATASET

# %% [markdown]
# ## FASTTEXT

# %%
df = pd.read_excel("results/10-Fold-fasttext-mfrc.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy  \
# 0       1      AdaBoostClassifier     0.461              0.432
# 1       1       BaggingClassifier     0.973              0.931
# 2       1             BernoulliNB     0.873              0.769
# 3       1  CalibratedClassifierCV     0.970              0.810
# 4       1  DecisionTreeClassifier     0.968              0.938
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.862              0.596
# 246    10       RidgeClassifierCV     0.862              0.596
# 247    10           SGDClassifier     0.950              0.759
# 248    10                     SVC     0.949              0.753
# 249    10          LGBMClassifier     0.988              0.939
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted  \
# 0              0.329               0.421         0.432            0.461
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro  \
# 0              AdaBoostClassifier    0.381             0.394           0.302
# 1               BaggingClassifier    0.973             0.909           0.941
# 2                     BernoulliNB    0.872             0.771           0.745
# 3          CalibratedClassifierCV    0.975              0.85           0.966
# 4          DecisionTreeClassifier    0.965               0.9           0.902
# 5                 DummyClassifier    0.268             0.125           0.034
# 6             ExtraTreeClassifier    0.795             0.657           0.657
# 7            ExtraTreesClassifier    0.965             0.796           0.947
# 8                      GaussianNB    0.895             0.884           0.781
# 9            KNeighborsClassifier    0.758             0.524           0.672
# 10               LabelPropagation    0.202             0.135           0.398
# ...

# %%
result.to_excel("results/avg-10-Fold-fasttext-mfrc.xlsx")

# %% [markdown]
# ## GLOVE

# %%
df = pd.read_excel("results/10-Fold-glove-mfrc.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy
# 0       1      AdaBoostClassifier     0.461              0.432  \
# 1       1       BaggingClassifier     0.975              0.933
# 2       1             BernoulliNB     0.675              0.677
# 3       1  CalibratedClassifierCV     0.973              0.820
# 4       1  DecisionTreeClassifier     0.966              0.919
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.859              0.595
# 246    10       RidgeClassifierCV     0.859              0.595
# 247    10           SGDClassifier     0.948              0.768
# 248    10                     SVC     0.959              0.773
# 249    10          LGBMClassifier     0.987              0.925
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted
# 0              0.329               0.421         0.432            0.461  \
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro
# 0              AdaBoostClassifier    0.388             0.394           0.302  \
# 1               BaggingClassifier    0.975             0.914           0.946
# 2                     BernoulliNB    0.672             0.658           0.559
# 3          CalibratedClassifierCV    0.976             0.864           0.966
# 4          DecisionTreeClassifier    0.965             0.904           0.906
# 5                 DummyClassifier    0.268             0.125           0.034
# 6             ExtraTreeClassifier    0.794             0.655           0.653
# 7            ExtraTreesClassifier    0.959             0.772            0.94
# 8                      GaussianNB    0.884             0.873           0.754
# 9            KNeighborsClassifier    0.742             0.522           0.671
# 10               LabelPropagation    0.229             0.153           0.483
# ...

# %%
result.to_excel("results/avg-10-Fold-glove-mfrc.xlsx")

# %% [markdown]
# ## BERT

# %%
df = pd.read_excel("results/10-Fold-BERT-mfrc.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy
# 0       1      AdaBoostClassifier     0.461              0.432  \
# 1       1       BaggingClassifier     0.979              0.947
# 2       1             BernoulliNB     0.552              0.490
# 3       1  CalibratedClassifierCV     0.957              0.721
# 4       1  DecisionTreeClassifier     0.971              0.916
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.865              0.598
# 246    10       RidgeClassifierCV     0.864              0.597
# 247    10           SGDClassifier     0.955              0.845
# 248    10                     SVC     0.945              0.731
# 249    10          LGBMClassifier     0.990              0.951
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted
# 0              0.329               0.421         0.432            0.461  \
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro
# 0              AdaBoostClassifier    0.388             0.394           0.302  \
# 1               BaggingClassifier    0.976             0.915           0.943
# 2                     BernoulliNB    0.571             0.514            0.46
# 3          CalibratedClassifierCV    0.962             0.744           0.829
# 4          DecisionTreeClassifier    0.973             0.919           0.921
# 5                 DummyClassifier    0.268             0.125           0.034
# 6             ExtraTreeClassifier    0.693             0.569           0.569
# 7            ExtraTreesClassifier    0.955             0.764           0.932
# 8                      GaussianNB    0.052             0.252           0.069
# 9            KNeighborsClassifier    0.806             0.586           0.714
# 10               LabelPropagation     0.74             0.579           0.723
# ...

# %%
result.to_excel("results/avg-10-Fold-BERT-mfrc.xlsx")

# %% [markdown]
# ## TFIDF

# %%
df = pd.read_excel("results/10-Fold-tfdif-mfrc.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy
# 0       1      AdaBoostClassifier     0.461              0.432  \
# 1       1       BaggingClassifier     0.980              0.949
# 2       1             BernoulliNB     0.861              0.762
# 3       1  CalibratedClassifierCV     0.971              0.842
# 4       1  DecisionTreeClassifier     0.979              0.942
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.863              0.599
# 246    10       RidgeClassifierCV     0.863              0.599
# 247    10           SGDClassifier     0.942              0.754
# 248    10                     SVC     0.947              0.734
# 249    10          LGBMClassifier     0.990              0.948
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted
# 0              0.329               0.421         0.432            0.461  \
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro
# 0              AdaBoostClassifier    0.388             0.394           0.302  \
# 1               BaggingClassifier    0.979             0.921           0.946
# 2                     BernoulliNB    0.863             0.745           0.724
# 3          CalibratedClassifierCV    0.975             0.862           0.961
# 4          DecisionTreeClassifier    0.978             0.927            0.93
# 5                 DummyClassifier    0.268             0.125           0.034
# 6             ExtraTreeClassifier     0.91             0.809           0.811
# 7            ExtraTreesClassifier    0.981             0.882           0.968
# 8                      GaussianNB    0.473             0.539            0.59
# 9            KNeighborsClassifier    0.615             0.441           0.565
# 10               LabelPropagation    0.448             0.346           0.543
# ...

# %%
result.to_excel("results/avg-10-Fold-tfdif-mfrc.xlsx")

# %% [markdown]
# ## WORD2VEC

# %%
df = pd.read_excel("results/10-Fold-word2vec-mfrc.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy
# 0       1      AdaBoostClassifier     0.461              0.432  \
# 1       1       BaggingClassifier     0.971              0.924
# 2       1             BernoulliNB     0.746              0.719
# 3       1  CalibratedClassifierCV     0.971              0.811
# 4       1  DecisionTreeClassifier     0.970              0.942
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.859              0.590
# 246    10       RidgeClassifierCV     0.859              0.590
# 247    10           SGDClassifier     0.946              0.766
# 248    10                     SVC     0.947              0.754
# 249    10          LGBMClassifier     0.989              0.932
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted
# 0              0.329               0.421         0.432            0.461  \
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro
# 0              AdaBoostClassifier    0.388             0.394           0.302  \
# 1               BaggingClassifier    0.973             0.904           0.943
# 2                     BernoulliNB     0.75             0.707           0.615
# 3          CalibratedClassifierCV    0.975             0.855           0.966
# 4          DecisionTreeClassifier    0.965             0.906           0.905
# 5                 DummyClassifier    0.268             0.125           0.034
# 6             ExtraTreeClassifier    0.794             0.669           0.668
# 7            ExtraTreesClassifier    0.961             0.778           0.942
# 8                      GaussianNB    0.896             0.884           0.772
# 9            KNeighborsClassifier    0.745             0.526           0.662
# 10               LabelPropagation    0.211             0.141           0.451
# ...

# %%
result.to_excel("results/avg-10-Fold-word2vec-mfrc.xlsx")

# %% [markdown]
# ## ANALYSIS

# %%
fasttext = pd.read_excel("results/avg-10-Fold-fasttext-mfrc.xlsx")
del fasttext['Unnamed: 0']
fasttext = fasttext.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
fasttext
# Out:
#                             Model  Accuracy  Balanced Accuracy
# 24                 LGBMClassifier     0.992              0.944  \
# 14             LogisticRegression     0.979              0.920
# 13                      LinearSVC     0.976              0.898
# 3          CalibratedClassifierCV     0.975              0.850
# 1               BaggingClassifier     0.973              0.909
# 4          DecisionTreeClassifier     0.965              0.900
# 7            ExtraTreesClassifier     0.965              0.796
# 12     LinearDiscriminantAnalysis     0.963              0.931
# 19         RandomForestClassifier     0.960              0.779
# 23                            SVC     0.954              0.769
# 17                     Perceptron     0.953              0.828
# 22                  SGDClassifier     0.953              0.764
# 16    PassiveAggressiveClassifier     0.947              0.805
# 18  QuadraticDiscriminantAnalysis     0.901              0.754
# ...

# %%
glove = pd.read_excel("results/avg-10-Fold-glove-mfrc.xlsx")
del glove['Unnamed: 0']
glove = glove.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
glove
# Out:
#                             Model  Accuracy  Balanced Accuracy
# 24                 LGBMClassifier     0.992              0.941  \
# 14             LogisticRegression     0.980              0.922
# 13                      LinearSVC     0.977              0.901
# 3          CalibratedClassifierCV     0.976              0.864
# 1               BaggingClassifier     0.975              0.914
# 4          DecisionTreeClassifier     0.965              0.904
# 12     LinearDiscriminantAnalysis     0.962              0.932
# 7            ExtraTreesClassifier     0.959              0.772
# 23                            SVC     0.957              0.776
# 19         RandomForestClassifier     0.953              0.755
# 22                  SGDClassifier     0.952              0.764
# 17                     Perceptron     0.951              0.813
# 16    PassiveAggressiveClassifier     0.949              0.818
# 18  QuadraticDiscriminantAnalysis     0.929              0.788
# ...

# %%
bert = pd.read_excel("results/avg-10-Fold-BERT-mfrc.xlsx")
del bert['Unnamed: 0']
bert = bert.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
bert
# Out:
#                             Model  Accuracy  Balanced Accuracy
# 24                 LGBMClassifier     0.993              0.955  \
# 14             LogisticRegression     0.979              0.925
# 1               BaggingClassifier     0.976              0.915
# 4          DecisionTreeClassifier     0.973              0.919
# 13                      LinearSVC     0.973              0.891
# 12     LinearDiscriminantAnalysis     0.967              0.931
# 3          CalibratedClassifierCV     0.962              0.744
# 22                  SGDClassifier     0.955              0.800
# 7            ExtraTreesClassifier     0.955              0.764
# 23                            SVC     0.952              0.734
# 17                     Perceptron     0.948              0.837
# 16    PassiveAggressiveClassifier     0.947              0.807
# 19         RandomForestClassifier     0.944              0.732
# 20                RidgeClassifier     0.866              0.594
# ...

# %%
tfdif = pd.read_excel("results/avg-10-Fold-tfdif-mfrc.xlsx")
del tfdif['Unnamed: 0']
tfdif = tfdif.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
tfdif
# Out:
#                             Model  Accuracy  Balanced Accuracy
# 24                 LGBMClassifier     0.994              0.965  \
# 19         RandomForestClassifier     0.981              0.883
# 7            ExtraTreesClassifier     0.981              0.882
# 1               BaggingClassifier     0.979              0.921
# 14             LogisticRegression     0.979              0.914
# 4          DecisionTreeClassifier     0.978              0.927
# 13                      LinearSVC     0.976              0.900
# 3          CalibratedClassifierCV     0.975              0.862
# 12     LinearDiscriminantAnalysis     0.964              0.934
# 16    PassiveAggressiveClassifier     0.954              0.816
# 23                            SVC     0.954              0.749
# 17                     Perceptron     0.953              0.827
# 22                  SGDClassifier     0.952              0.767
# 6             ExtraTreeClassifier     0.910              0.809
# ...

# %%
w2c = pd.read_excel("results/avg-10-Fold-word2vec-mfrc.xlsx")
del w2c['Unnamed: 0']
w2c = w2c.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
w2c
# Out:
#                             Model  Accuracy  Balanced Accuracy
# 24                 LGBMClassifier     0.991              0.945  \
# 14             LogisticRegression     0.979              0.924
# 13                      LinearSVC     0.976              0.899
# 3          CalibratedClassifierCV     0.975              0.855
# 1               BaggingClassifier     0.973              0.904
# 4          DecisionTreeClassifier     0.965              0.906
# 12     LinearDiscriminantAnalysis     0.962              0.931
# 7            ExtraTreesClassifier     0.961              0.778
# 19         RandomForestClassifier     0.956              0.768
# 23                            SVC     0.955              0.775
# 22                  SGDClassifier     0.952              0.762
# 17                     Perceptron     0.951              0.809
# 16    PassiveAggressiveClassifier     0.946              0.824
# 18  QuadraticDiscriminantAnalysis     0.921              0.778
# ...

# %% [markdown]
# # DAVIDSON + MFRC

# %% [markdown]
# ## FASTTEXT

# %%
df = pd.read_excel("results/10-Fold-fasttext-all.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy  \
# 0       1      AdaBoostClassifier     0.367              0.388
# 1       1       BaggingClassifier     0.986              0.942
# 2       1             BernoulliNB     0.837              0.724
# 3       1  CalibratedClassifierCV     0.984              0.897
# 4       1  DecisionTreeClassifier     0.982              0.922
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.913              0.586
# 246    10       RidgeClassifierCV     0.913              0.586
# 247    10           SGDClassifier     0.962              0.715
# 248    10                     SVC     0.972              0.806
# 249    10          LGBMClassifier     0.995              0.960
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted  \
# 0              0.305               0.455         0.388            0.367
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro  \
# 0              AdaBoostClassifier    0.507              0.37           0.277
# 1               BaggingClassifier    0.986             0.929           0.942
# 2                     BernoulliNB    0.834             0.734           0.693
# 3          CalibratedClassifierCV    0.985             0.887           0.968
# 4          DecisionTreeClassifier    0.982             0.914           0.926
# 5                 DummyClassifier    0.333             0.125           0.042
# 6             ExtraTreeClassifier     0.81             0.652            0.66
# 7            ExtraTreesClassifier    0.981             0.822           0.965
# 8                      GaussianNB    0.909             0.904           0.758
# 9            KNeighborsClassifier    0.846             0.605           0.794
# 10               LabelPropagation    0.252             0.163           0.617
# ...

# %%
result.to_excel("results/avg-10-Fold-fasttext-all.xlsx")

# %% [markdown]
# ## GLOVE

# %%
df = pd.read_excel("results/10-Fold-glove-all.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy  \
# 0       1      AdaBoostClassifier     0.555              0.369
# 1       1       BaggingClassifier     0.984              0.899
# 2       1             BernoulliNB     0.621              0.598
# 3       1  CalibratedClassifierCV     0.985              0.896
# 4       1  DecisionTreeClassifier     0.978              0.884
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.912              0.583
# 246    10       RidgeClassifierCV     0.912              0.583
# 247    10           SGDClassifier     0.966              0.735
# 248    10                     SVC     0.974              0.815
# 249    10          LGBMClassifier     0.834              0.623
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted  \
# 0              0.269               0.392         0.369            0.555
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro  \
# 0              AdaBoostClassifier    0.526             0.365           0.275
# 1               BaggingClassifier    0.986             0.921           0.943
# 2                     BernoulliNB    0.629             0.588           0.486
# 3          CalibratedClassifierCV    0.986             0.887           0.968
# 4          DecisionTreeClassifier     0.98             0.911           0.913
# 5                 DummyClassifier    0.333             0.125           0.042
# 6             ExtraTreeClassifier    0.791             0.608           0.607
# 7            ExtraTreesClassifier    0.978             0.799           0.978
# 8                      GaussianNB    0.883             0.881           0.718
# 9            KNeighborsClassifier    0.834             0.585           0.799
# 10               LabelPropagation    0.342             0.225           0.625
# ...

# %%
result.to_excel("results/avg-10-Fold-glove-all.xlsx")

# %% [markdown]
# ## BERT

# %%
df = pd.read_excel("results/10-Fold-BERT-all.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy  \
# 0       1      AdaBoostClassifier     0.367              0.389
# 1       1       BaggingClassifier     0.986              0.897
# 2       1             BernoulliNB     0.700              0.520
# 3       1  CalibratedClassifierCV     0.976              0.761
# 4       1  DecisionTreeClassifier     0.986              0.907
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.913              0.583
# 246    10       RidgeClassifierCV     0.913              0.583
# 247    10           SGDClassifier     0.966              0.733
# 248    10                     SVC     0.974              0.787
# 249    10          LGBMClassifier     0.995              0.972
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted  \
# 0              0.323               0.490         0.389            0.367
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro  \
# 0              AdaBoostClassifier      0.5             0.368           0.282
# 1               BaggingClassifier    0.988             0.933           0.949
# 2                     BernoulliNB     0.71             0.544            0.53
# 3          CalibratedClassifierCV    0.977             0.745           0.851
# 4          DecisionTreeClassifier    0.986             0.922            0.93
# 5                 DummyClassifier    0.333             0.125           0.042
# 6             ExtraTreeClassifier    0.806             0.629           0.634
# 7            ExtraTreesClassifier    0.977             0.797           0.972
# 8                      GaussianNB    0.037              0.25            0.05
# 9            KNeighborsClassifier    0.874             0.617           0.743
# 10               LabelPropagation    0.823             0.611           0.799
# ...

# %%
result.to_excel("results/avg-10-Fold-BERT-all.xlsx")

# %% [markdown]
# ## TFIDF

# %%
df = pd.read_excel("results/10-Fold-tfdif-all.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy  \
# 0       1      AdaBoostClassifier     0.567              0.376
# 1       1       BaggingClassifier     0.989              0.918
# 2       1             BernoulliNB     0.850              0.726
# 3       1  CalibratedClassifierCV     0.984              0.877
# 4       1  DecisionTreeClassifier     0.989              0.940
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.911              0.581
# 246    10       RidgeClassifierCV     0.911              0.581
# 247    10           SGDClassifier     0.960              0.728
# 248    10                     SVC     0.972              0.780
# 249    10          LGBMClassifier     0.996              0.980
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted  \
# 0              0.337               0.519         0.376            0.567
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro  \
# 0              AdaBoostClassifier     0.51             0.369           0.285
# 1               BaggingClassifier     0.99             0.936           0.953
# 2                     BernoulliNB    0.852             0.733           0.694
# 3          CalibratedClassifierCV    0.985             0.879           0.958
# 4          DecisionTreeClassifier    0.988             0.936           0.939
# 5                 DummyClassifier    0.333             0.125           0.042
# 6             ExtraTreeClassifier    0.908              0.78           0.782
# 7            ExtraTreesClassifier    0.991             0.903           0.982
# 8                      GaussianNB    0.669             0.648           0.581
# 9            KNeighborsClassifier    0.722             0.467           0.662
# 10               LabelPropagation    0.611             0.407           0.634
# ...

# %%
result.to_excel("results/avg-10-Fold-tfdif-all.xlsx")

# %% [markdown]
# ## WORD2VEC

# %%
df = pd.read_excel("results/10-Fold-word2vec-all.xlsx")
del df['Unnamed: 0']
df
# Out:
#      Fold                   Model  Accuracy  Balanced Accuracy  \
# 0       1      AdaBoostClassifier     0.365              0.389
# 1       1       BaggingClassifier     0.986              0.927
# 2       1             BernoulliNB     0.642              0.634
# 3       1  CalibratedClassifierCV     0.985              0.882
# 4       1  DecisionTreeClassifier     0.979              0.907
# ..    ...                     ...       ...                ...
# 245    10         RidgeClassifier     0.909              0.581
# 246    10       RidgeClassifierCV     0.909              0.581
# 247    10           SGDClassifier     0.962              0.736
# 248    10                     SVC     0.972              0.819
# 249    10          LGBMClassifier     0.881              0.684
#
#      Precision-Macro  Precision-Weighted  Recall-Macro  Recall-Weighted  \
# 0              0.298               0.449         0.389            0.365
# ...

# %%
models = df['Model'].copy()[:25].to_list()
models
# Out:
# ['AdaBoostClassifier',
#  'BaggingClassifier',
#  'BernoulliNB',
#  'CalibratedClassifierCV',
#  'DecisionTreeClassifier',
#  'DummyClassifier',
#  'ExtraTreeClassifier',
#  'ExtraTreesClassifier',
#  'GaussianNB',
#  'KNeighborsClassifier',
#  'LabelPropagation',
#  'LabelSpreading',
#  'LinearDiscriminantAnalysis',
#  'LinearSVC',
#  'LogisticRegression',
#  'NearestCentroid',
#  'PassiveAggressiveClassifier',
#  'Perceptron',
#  'QuadraticDiscriminantAnalysis',
#  'RandomForestClassifier',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SVC',
#  'LGBMClassifier']

# %%
result = get_avg_folds(df, models)
result
# Out:
#                             Model Accuracy Balanced Accuracy Precision-Macro  \
# 0              AdaBoostClassifier     0.51             0.369           0.279
# 1               BaggingClassifier    0.986             0.927           0.943
# 2                     BernoulliNB    0.651             0.618           0.509
# 3          CalibratedClassifierCV    0.985             0.889           0.967
# 4          DecisionTreeClassifier    0.982              0.92           0.924
# 5                 DummyClassifier    0.333             0.125           0.042
# 6             ExtraTreeClassifier     0.79             0.617            0.62
# 7            ExtraTreesClassifier    0.978              0.79           0.938
# 8                      GaussianNB    0.892             0.893           0.729
# 9            KNeighborsClassifier    0.835             0.589            0.81
# 10               LabelPropagation    0.328             0.212           0.632
# ...

# %%
result.to_excel("results/avg-10-Fold-word2vec-all.xlsx")

# %% [markdown]
# ## ANALYSIS

# %%
fasttext = pd.read_excel("results/avg-10-Fold-fasttext-all.xlsx")
del fasttext['Unnamed: 0']
fasttext = fasttext.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
fasttext
# Out:
#                             Model  Accuracy  Balanced Accuracy  \
# 14             LogisticRegression     0.990              0.941
# 1               BaggingClassifier     0.986              0.929
# 13                      LinearSVC     0.986              0.906
# 3          CalibratedClassifierCV     0.985              0.887
# 4          DecisionTreeClassifier     0.982              0.914
# 7            ExtraTreesClassifier     0.981              0.822
# 19         RandomForestClassifier     0.979              0.808
# 23                            SVC     0.975              0.818
# 12     LinearDiscriminantAnalysis     0.973              0.946
# 17                     Perceptron     0.972              0.827
# 16    PassiveAggressiveClassifier     0.971              0.831
# 22                  SGDClassifier     0.966              0.735
# 24                 LGBMClassifier     0.913              0.793
# 20                RidgeClassifier     0.911              0.590
# ...

# %%
glove = pd.read_excel("results/avg-10-Fold-glove-all.xlsx")
del glove['Unnamed: 0']
glove = glove.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
glove
# Out:
#                             Model  Accuracy  Balanced Accuracy  \
# 14             LogisticRegression     0.990              0.944
# 13                      LinearSVC     0.987              0.910
# 1               BaggingClassifier     0.986              0.921
# 3          CalibratedClassifierCV     0.986              0.887
# 4          DecisionTreeClassifier     0.980              0.911
# 7            ExtraTreesClassifier     0.978              0.799
# 23                            SVC     0.976              0.824
# 17                     Perceptron     0.974              0.846
# 19         RandomForestClassifier     0.973              0.770
# 12     LinearDiscriminantAnalysis     0.972              0.945
# 16    PassiveAggressiveClassifier     0.972              0.837
# 22                  SGDClassifier     0.966              0.739
# 18  QuadraticDiscriminantAnalysis     0.916              0.806
# 20                RidgeClassifier     0.911              0.591
# ...

# %%
bert = pd.read_excel("results/avg-10-Fold-BERT-all.xlsx")
del bert['Unnamed: 0']
bert = bert.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
bert
# Out:
#                             Model  Accuracy  Balanced Accuracy  \
# 14             LogisticRegression     0.990              0.937
# 1               BaggingClassifier     0.988              0.933
# 4          DecisionTreeClassifier     0.986              0.922
# 13                      LinearSVC     0.985              0.896
# 12     LinearDiscriminantAnalysis     0.979              0.948
# 7            ExtraTreesClassifier     0.977              0.797
# 3          CalibratedClassifierCV     0.977              0.745
# 23                            SVC     0.974              0.791
# 17                     Perceptron     0.970              0.864
# 16    PassiveAggressiveClassifier     0.970              0.839
# 19         RandomForestClassifier     0.970              0.750
# 22                  SGDClassifier     0.969              0.747
# 21              RidgeClassifierCV     0.912              0.590
# 20                RidgeClassifier     0.912              0.590
# ...

# %%
tfdif = pd.read_excel("results/avg-10-Fold-tfdif-all.xlsx")
del tfdif['Unnamed: 0']
tfdif = tfdif.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
tfdif
# Out:
#                             Model  Accuracy  Balanced Accuracy  \
# 7            ExtraTreesClassifier     0.991              0.903
# 14             LogisticRegression     0.990              0.937
# 1               BaggingClassifier     0.990              0.936
# 19         RandomForestClassifier     0.990              0.899
# 4          DecisionTreeClassifier     0.988              0.936
# 13                      LinearSVC     0.987              0.900
# 3          CalibratedClassifierCV     0.985              0.879
# 23                            SVC     0.976              0.786
# 12     LinearDiscriminantAnalysis     0.973              0.946
# 17                     Perceptron     0.971              0.837
# 16    PassiveAggressiveClassifier     0.971              0.822
# 22                  SGDClassifier     0.967              0.745
# 20                RidgeClassifier     0.911              0.590
# 21              RidgeClassifierCV     0.911              0.590
# ...

# %%
w2c = pd.read_excel("results/avg-10-Fold-word2vec-all.xlsx")
del w2c['Unnamed: 0']
w2c = w2c.sort_values(by = ["Accuracy","Balanced Accuracy", "Precision-Macro",  "Precision-Weighted", "Recall-Macro", "Recall-Weighted", "F1-Score-Macro", "F1-Score-Weighted"],  ascending=False)
w2c
# Out:
#                             Model  Accuracy  Balanced Accuracy  \
# 14             LogisticRegression     0.990              0.944
# 13                      LinearSVC     0.987              0.911
# 1               BaggingClassifier     0.986              0.927
# 3          CalibratedClassifierCV     0.985              0.889
# 4          DecisionTreeClassifier     0.982              0.920
# 7            ExtraTreesClassifier     0.978              0.790
# 23                            SVC     0.975              0.822
# 17                     Perceptron     0.973              0.836
# 16    PassiveAggressiveClassifier     0.973              0.836
# 19         RandomForestClassifier     0.973              0.772
# 12     LinearDiscriminantAnalysis     0.972              0.945
# 22                  SGDClassifier     0.965              0.738
# 24                 LGBMClassifier     0.927              0.821
# 18  QuadraticDiscriminantAnalysis     0.915              0.807
# ...
